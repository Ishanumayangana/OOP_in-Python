# %%
class Bikes:
    def __init__(self, brandname, year):
        self.brandname = brandname
        self.year = year

bmw = Bikes("bmw", 2021)
ducati = Bikes("ducati", 2020)

print("{} Year of manufacture {}".format(bmw.brandname, bmw.year))
print("{} Year of manufacture {}".format(ducati.brandname, ducati.year))
# Out:
# bmw Year of manufacture 2021
# ducati Year of manufacture 2020

# %%
class Bikes:
    def __init__(self, brandname, year):
        self.brandname = brandname
        self.year = year

    def topspeed(self, topspeed=None):
        if topspeed:
            return "{} topspeed is {}".format(self.brandname, topspeed)
        else:
            return "{} topspeed is not available".format(self.brandname)

    def type(self):
        return "{} is a type of bike".format(self.brandname)

bmw = Bikes("bmw", 2022)
print(bmw.topspeed(220))  # This will print the top speed provided
print(bmw.topspeed())     # This will print a message that top speed is not available
print(bmw.type())          # This will print the type of the bike
# Out:
# bmw topspeed is 220
# bmw topspeed is not available
# bmw is a type of bike

# %% [markdown]
# Single level inheritence

# %%
class Animal:
  def sound(self):
    print("Animal making sound")

class Cat(Animal):
  def Meow(self):
    print("Cat Meows")

d = Cat()
d.Meow()
d.sound()
# Out:
# Cat Meows
# Animal making sound

# %% [markdown]
# Multi level inheritence

# %%
class Animal:
  def sound(self):
    print("Animal making sound")

class Cat(Animal):
  def Meow(self):
    print("Cat Meows")

class CatChild(Cat):
  def eat(self):
    print("Eating bread....")

d = CatChild()
d.Meow()
d.sound()
d.eat()
# Out:
# Cat Meows
# Animal making sound
# Eating bread....

# %% [markdown]
# Polymorphism

# %%
class Parrot:
  def fly(self):
    print("Parrot can fly")
  def swim(self):
    print("Parrot can't swim")

class Penguin:
  def fly(self):
    print("Penguin can't fly")
  def swim(self):
    print("Penguin can swim")

def flying_test(bird):
  bird.fly()

blu = Parrot()
peggy = Penguin()

flying_test(blu)
flying_test(peggy)
# Out:
# Parrot can fly
# Penguin can't fly

# %% [markdown]
# Encapsulation

# %%
class Cars:
    def __init__(self):
      self.__maxprice = 90000
    def sell(self):
      print("Selling Price: {}".format(self.__maxprice))

    def setMaxPrice(self, price):
      self.__maxprice = price

c = Cars()
c.sell()

c.__maxprice = 100000
c.sell()

c.setMaxPrice(1000)
c.sell()
# Out:
# Selling Price: 90000
# Selling Price: 90000
# Selling Price: 1000

# %% [markdown]
# Hierarchical Inheritance

# %%
class employee():
 def __init__(self,name,age,salary):

   self.name = name
   self.age = age
   self.salary = salary

class childemployee1(employee):
 def __init__(self,name,age,salary):

   self.name = name
   self.age = age
   self.salary = salary

class childemployee2(employee):
 def __init__(self,name,age,salary):

   self.name = name
   self.age = age
   self.salary = salary

emp1 = childemployee1('ishan',25,1000)
emp2 = childemployee2('kavi',27,2000)

print(emp1.age)
print(emp2.age)
# Out:
# 25
# 27

# %% [markdown]
# Abstraction

# %%
class Car():
  def mileage(self):
    pass

class BMW(Car):
  def mileage(self):
    print("The mileage is 30kmph")

class jaguar(Car):
  def mileage(self):
    print("The mileage is 25kmph")

class RangeRower(Car):
  def mileage(self):
    print("The mileage is 24kmph")

class Renault(Car):
  def mileage(self):
    print("The mileage is 27kmph")

t = BMW ()
t.mileage()

r = Renault ()
r.mileage()

s = jaguar ()
s.mileage()

c = RangeRower ()
c.mileage()
# Out:
# The mileage is 30kmph
# The mileage is 27kmph
# The mileage is 25kmph
# The mileage is 24kmph
